# %%
import os
from os.path import join

osms_path = ('X:\TrueBeam2871\OSMS Upgrade')

for root, dirs, files in os.walk(osms_path,topdown=False):
#    if root == osms_path:
    print('OSMS Directory: %s' % root)
    for name in dirs:
        print('\t Patient {0}'.format(name))
# Out:
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\161227 150942
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170304 115634
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170304 115938
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170304 120130
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170306 102507
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170306 110112
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170306 113106
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170306 114001
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170306 122533
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170306 130446
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170306 142835
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170306 164843
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170308 095223
# OSMS Directory: X:\TrueBeam2871\OSMS Upgrade\000-OSMS\170308 101130
# ...
